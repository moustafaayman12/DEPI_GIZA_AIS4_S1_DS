# %%
#task one
class process_in_email:
   
        
    def __init__(self, email):
        self.email = email
    def get_username(self):
        username = self.email.split("@")[0]
        print("Username:", username)
    def get_domain(self):
        domain= self.email.split("@")[1]
        domain= domain.split(".")[0]
        print("Domain:", domain)
        
    def validate_email(self,email):  
        email_split = self.email.split("@")
       
       
        if email.count("@") == 1 :
            
            if email.count(".") >= 1 :
                if "."in email_split[1]:
                    print("Valid email address.")
                else:
                    print("Invalid email address.")
                    
            else:
                print("Invalid email address.")        
        else:
            print("Invalid email address.")            
                    
        if email.endswith(".com"):
            print("commercial domain")    
        elif email.endswith(".edu"):
            print("edution domain")    
        else:
            print("other domain")
            
            
                   
email_1 = process_in_email("mostafa@gmail.edu")
email_1.validate_email(email_1.email)
email_1.get_username()
email_1.get_domain()
# Out:
# Valid email address.
# edution domain
# Username: mostafa
# Domain: gmail

# %%
#task two
message ="###!!@mocleW EPGTQ!!!6789"
massage_slice =message[6:18]
print(massage_slice)
message_replace = message.replace("mocleW","Welcome")
print(message_replace)
massage_slice_split = massage_slice.split(" ")
reversed_message=massage_slice_split[0][::-1] 
print(reversed_message)
scound_word="EPGTQ"
scound_word=scound_word.replace("EPGTQ","PGTQ")
decode=" ".join(reversed_message + " " + scound_word)
print(f"decoded message: {decode}")
# Out:
# mocleW EPGTQ
# ###!!@Welcome EPGTQ!!!6789
# Welcom
# decoded message: W e l c o m   P G T Q

# %%
#task three
message = "&&&**$gnirtS PLIO!!@1234"
massage_slice =message[6:17]
print(massage_slice)
message_slice_split1=massage_slice.split(" ")
print(message_slice_split1[0])
reversed_message2=message_slice_split1[0][::-1]
print(reversed_message2) 
first_word=reversed_message2
scound_word="PLIO"
def shifted_vowels(x):
    word = x
    
    for char in word:
        if char == "I":
            word = word.replace("I", "E")
        elif char == "O":
            word = word.replace("O", "U")
        
    return word

scound_word=shifted_vowels(scound_word)

decode=" ".join(first_word + " " + scound_word)
print(f"decoded message: {decode}")
# Out:
# gnirtS PLIO
# gnirtS
# String
# decoded message: S t r i n g   P L E U

# %%
 #task three in another way
class preocess_in_message: 
    def __init__(self, message):
        self.message = message

    def preprocess_message(self):
        m=int(input("Enter start index for slicing: "))
        n=int(input("Enter end index for slicing: "))
    
        massage_slice = self.message[m:n]
        print("Sliced message:", massage_slice)


        message_slice_split1 = massage_slice.split(" ")
        print("First word in slice:", message_slice_split1[0])

     
        first_word = message_slice_split1[0][::-1]
        print("Reversed first word:", first_word)

        scound_word = message_slice_split1[1]

       
        def shifted_vowels(x):
            
             new_word = ""
             for char in x:
                 
                  if char == "I":
                        new_word += "E"
                  elif char == "O":
                       new_word += "U"
                  elif char == "E":
                         new_word += "A"
                  else:
                        new_word += char
             return new_word
   
        scound_word = shifted_vowels(scound_word)
      
        decode = first_word + " " + scound_word
        print(f"decoded message: {decode}")


user_input = input("Enter your message: ")
processor = preocess_in_message(user_input)
processor.preprocess_message()
# Out:
# Sliced message: gnirtS PLIO
# First word in slice: gnirtS
# Reversed first word: String
# decoded message: String PLEU

# %%
 #task three in another way
class preocess_in_message: 
    def __init__(self, message):
        self.message = message

    def preprocess_message(self):
        m=int(input("Enter start index for slicing: "))
        n=int(input("Enter end index for slicing: "))
    
        massage_slice = self.message[m:n]
        print("Sliced message:", massage_slice)


        message_slice_split1 = massage_slice.split(" ")
        print("First word in slice:", message_slice_split1[0])

     
        first_word = message_slice_split1[0][::-1]
        print("Reversed first word:", first_word)

        scound_word = message_slice_split1[1]

       
        def shifted_vowels(x):
            
             new_word = ""
             for char in x:
                 
                 # if char == "I":
                        #new_word += "E"
                  if char == "U":    
                      
                     new_word += "O"
                  elif char == "E":
                    new_word += "A"
                  else:
                    new_word += char
             return new_word
   
        scound_word = shifted_vowels(scound_word)
      
        decode = first_word + " " + scound_word
        print(f"decoded message: {decode}")


user_input = input("Enter your message: ")
processor = preocess_in_message(user_input)
processor.preprocess_message()
# Out:
# Sliced message: yalpstcejorp EPUVT
# First word in slice: yalpstcejorp
# Reversed first word: projectsplay
# decoded message: projectsplay APOVT
